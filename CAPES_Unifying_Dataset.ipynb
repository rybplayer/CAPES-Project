# %% [markdown]
# # Project CAPES: Combining Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# Make an array of department names of files in CAPES_CSV
Dept_Array = np.array([])
with open('Capes_Dept.txt','r') as f:
    for dept in f:
        Dept_Array = np.append(Dept_Array,dept[:-1])
        
Dept_Array
# Out:
# array(['RELI', 'LIT', 'PHIL', 'FPMU', 'ELWR', 'MUIR', 'TWS', 'COMM',
#        'HDP', 'ENVR', 'CAT', 'STPA', 'INTL', 'CONT', 'BENG', 'PSYC',
#        'LAWS', 'LATI', 'WARR', 'ERC', 'CGS', 'ECON', 'BIOL', 'HIST',
#        'HUM', 'PHYS', 'REV', 'ANTH', 'VIS', 'CSE', 'SE', 'MGT', 'THEA',
#        'ICAM', 'SXTH', 'EDS', 'DOC', 'COGS', 'JAPN', 'SOCI', 'NANO',
#        'SIO', 'HMNR', 'JUDA', 'USP', 'ETHN', 'ENG', 'MUS', 'FILM', 'MMW',
#        'CENG', 'MATH', 'CHEM', 'TMC', 'CHIN', 'WCWP', 'POLI', 'MAE',
#        'ECE', 'ESYS', 'LIGN', 'DSC', 'PHYS', 'SYN'], dtype='<U32')

# %%
# Takes in a department and formats it into a proper file
def Dept_to_Filename(dept):
    return "CAPES_CSV/CAPES_"+dept+".csv"
Dept_to_Filename_v = np.vectorize(Dept_to_Filename)

# Convert the department array into their proper filenames
Filename_Array = Dept_to_Filename_v(Dept_Array)
Filename_Array
# Out:
# array(['CAPES_CSV/CAPES_RELI.csv', 'CAPES_CSV/CAPES_LIT.csv',
#        'CAPES_CSV/CAPES_PHIL.csv', 'CAPES_CSV/CAPES_FPMU.csv',
#        'CAPES_CSV/CAPES_ELWR.csv', 'CAPES_CSV/CAPES_MUIR.csv',
#        'CAPES_CSV/CAPES_TWS.csv', 'CAPES_CSV/CAPES_COMM.csv',
#        'CAPES_CSV/CAPES_HDP.csv', 'CAPES_CSV/CAPES_ENVR.csv',
#        'CAPES_CSV/CAPES_CAT.csv', 'CAPES_CSV/CAPES_STPA.csv',
#        'CAPES_CSV/CAPES_INTL.csv', 'CAPES_CSV/CAPES_CONT.csv',
#        'CAPES_CSV/CAPES_BENG.csv', 'CAPES_CSV/CAPES_PSYC.csv',
#        'CAPES_CSV/CAPES_LAWS.csv', 'CAPES_CSV/CAPES_LATI.csv',
#        'CAPES_CSV/CAPES_WARR.csv', 'CAPES_CSV/CAPES_ERC.csv',
#        'CAPES_CSV/CAPES_CGS.csv', 'CAPES_CSV/CAPES_ECON.csv',
#        'CAPES_CSV/CAPES_BIOL.csv', 'CAPES_CSV/CAPES_HIST.csv',
#        'CAPES_CSV/CAPES_HUM.csv', 'CAPES_CSV/CAPES_PHYS.csv',
#        'CAPES_CSV/CAPES_REV.csv', 'CAPES_CSV/CAPES_ANTH.csv',
#        'CAPES_CSV/CAPES_VIS.csv', 'CAPES_CSV/CAPES_CSE.csv',
#        'CAPES_CSV/CAPES_SE.csv', 'CAPES_CSV/CAPES_MGT.csv',
#        'CAPES_CSV/CAPES_THEA.csv', 'CAPES_CSV/CAPES_ICAM.csv',
#        'CAPES_CSV/CAPES_SXTH.csv', 'CAPES_CSV/CAPES_EDS.csv',
#        'CAPES_CSV/CAPES_DOC.csv', 'CAPES_CSV/CAPES_COGS.csv',
#        'CAPES_CSV/CAPES_JAPN.csv', 'CAPES_CSV/CAPES_SOCI.csv',
#        'CAPES_CSV/CAPES_NANO.csv', 'CAPES_CSV/CAPES_SIO.csv',
#        'CAPES_CSV/CAPES_HMNR.csv', 'CAPES_CSV/CAPES_JUDA.csv',
#        'CAPES_CSV/CAPES_USP.csv', 'CAPES_CSV/CAPES_ETHN.csv',
#        'CAPES_CSV/CAPES_ENG.csv', 'CAPES_CSV/CAPES_MUS.csv',
#        'CAPES_CSV/CAPES_FILM.csv', 'CAPES_CSV/CAPES_MMW.csv',
#        'CAPES_CSV/CAPES_CENG.csv', 'CAPES_CSV/CAPES_MATH.csv',
#        'CAPES_CSV/CAPES_CHEM.csv', 'CAPES_CSV/CAPES_TMC.csv',
#        'CAPES_CSV/CAPES_CHIN.csv', 'CAPES_CSV/CAPES_WCWP.csv',
#        'CAPES_CSV/CAPES_POLI.csv', 'CAPES_CSV/CAPES_MAE.csv',
#        'CAPES_CSV/CAPES_ECE.csv', 'CAPES_CSV/CAPES_ESYS.csv',
#        'CAPES_CSV/CAPES_LIGN.csv', 'CAPES_CSV/CAPES_DSC.csv',
#        'CAPES_CSV/CAPES_PHYS.csv', 'CAPES_CSV/CAPES_SYN.csv'],
#       dtype='<U24')

# %%
Capes = [pd.read_csv(filename) for filename in Filename_Array]
Capes = pd.concat(Capes, ignore_index=True)
Capes
# Out:
#               Instructor                                         Course  Term  \
# 0        Kalleres, Dayna          RELI 1 - Introduction to Religion (A)  FA22
# 1          Rahimi, Babak                RELI 149 - Islam in America (A)  S122
# 2          Rahimi, Babak  RELI 101 - Tools&Methods/Studyof Religion (A)  WI22
# 3          Rahimi, Babak      RELI 188 - Special Topics in Religion (A)  WI22
# 4        Kalleres, Dayna          RELI 1 - Introduction to Religion (A)  FA21
# ...                  ...                                            ...   ...
# 61301  Gladstein, Jill M       SYN 1 - Perspectives/Changing Planet (0)  WI22
# 61302  Gladstein, Jill M       SYN 2 - Explorations/Changing Planet (0)  WI22
# 61303  Gladstein, Jill M       SYN 2 - Explorations/Changing Planet (0)  FA21
# 61304  Gladstein, Jill M       SYN 1 - Perspectives/Changing Planet (0)  SP21
# 61305  Gladstein, Jill M       SYN 1 - Perspectives/Changing Planet (0)  WI21
#
#        Enroll  Evals Made Rcmnd Class Rcmnd Instr  Study Hrs/wk  \
# 0          37          11       90.9%      100.0%          2.50
# 1          40           5      100.0%      100.0%          3.70
# 2          39          10       90.0%       90.0%          3.61
# 3          34          11       80.0%       90.0%          3.90
# 4          37          18       81.3%       75.0%          2.50
# ...       ...         ...         ...         ...           ...
# 61301     404         243       90.9%       93.4%          3.95
# 61302     191          93       77.0%       88.5%          4.18
# 61303     319         135       68.0%       74.4%          3.89
# 61304     235         107       90.6%       95.3%          5.15
# 61305     318         181       89.1%       91.3%          4.06
#
#       Avg Grade Expected Avg Grade Received
# 0               B (3.20)           A (4.00)
# 1              A- (3.80)          A- (3.98)
# 2              B+ (3.67)          A- (3.73)
# 3              A- (3.90)          A- (3.81)
# 4              A- (3.85)          A- (3.74)
# ...                  ...                ...
# 61301          A- (3.94)          A- (3.90)
# 61302          A- (3.79)          A- (3.89)
# 61303          A- (3.93)          A- (3.88)
# 61304          A- (3.85)          A- (3.88)
# 61305          A- (3.91)          A- (3.88)
#
# [61306 rows x 10 columns]

# %% [markdown]
# We save this pristine raw data as a `csv` file.

# %%
Capes.to_csv('Capes_raw.csv')
